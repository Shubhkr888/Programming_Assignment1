# %%
# Question 1
print ("Hello Python")
# Out:
# Hello Python

# %%
# Question 2
a = int(input("Enter a first number: "))
b = int(input("Enter a second number: "))

addition = a+b
division = a/b

print(f"Addition and division of {a} and {b} is {addition} and {division}")
# Out:
# Enter a first number: 2
# Enter a second number: 4
# Addition and division of 2 and 4 is 6 and 0.5

# %%
# Question 3
a = int(input("Enter height: "))
b = int(input("Enter base: "))

Area = 0.5*a*b

print(f"Area of a triangle is {Area} ")
# Out:
# Enter height: 5
# Enter base: 5
# Area of a triangle is 12.5

# %%
# Question 4
a = int(input("Enter a first number: "))
b = int(input("Enter a second number: "))

temp = a
a = b
b = temp

print(f"Swapped numbers is {a} and {b}")
# Out:
# Enter a first number: 3
# Enter a second number: 4
# Swapped numbers is 4 and 3

# %%
# Question 5

import random
randomNumber = random.randint(1,100)
print(f"Random number is {randomNumber}")
# Out:
# Random number is 4
